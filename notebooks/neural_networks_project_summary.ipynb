# %% [markdown]
#             # Neural networks project summary
#
#             This notebook gives a compact public view of the coursework workflow:
#
#             - dense baseline models;
#             - deeper feed-forward variants with regularization;
#             - later convolutional experiments;
#             - training-history inspection;
#             - final confusion-matrix review.
#
#             The original local notebook is not published directly because it still contains workstation-specific paths, local dataset references and checkpoint-heavy execution traces.

# %% [markdown]
#             ## Where to look in the repository
#
#             - `src/extract_notebook_result_figures.py` contains the helper used to export representative notebook outputs.
#             - `figures/training_history_reference.png` shows the behaviour of one representative training run.
#             - `figures/final_confusion_matrix.png` keeps the final class-by-class evaluation view.

# %% [markdown]
#             ## Training dynamics
#
#             ![Training history](../figures/training_history_reference.png)

# %% [markdown]
#             ## Final classification view
#
#             ![Confusion matrix](../figures/final_confusion_matrix.png)

# %%
            # Example command used to regenerate the public-safe figures
            # from the local notebook, when that notebook is available:
            #
            # python src/extract_notebook_result_figures.py <local_notebook.ipynb> figures
